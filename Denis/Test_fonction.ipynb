# %%
import Fonctions as Fct 
import Listes
import Generation_df as Gdf
import Nettoyage as Net

# %%
Donnees = Gdf.pd.DataFrame({"Date": [], "Chaine": [], "Part_de_marche": []})

# %%
Dates = Listes.date(31,12,6)
Chemins = Listes.chemin(Dates)

# %%
for i in range(len(Chemins)):
    arbre = Fct.arbre(Chemins[i])
    test = arbre.find("h1")
    test = str(test)
    if test != "<h1>Audiences TV du 27 novembre 2019 avec Tele 7</h1>" :
        V1 = Fct.Jour(arbre)
        V2 = Fct.Logo(arbre)
        V3 = Fct.Pdm(arbre)
        if len(V1) == 19 & len(V2) == 19 & len(V3) == 19:
            Donnees = Gdf.Donnee(V1,V2,V3,Donnees)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-982765930f74> in <module>()
#       1 for i in range(len(Chemins)):
# ----> 2     arbre = Fct.arbre(Chemins[i])
#       3     test = arbre.find("h1")
#       4     test = str(test)
#       5     if test != "<h1>Audiences TV du 27 novembre 2019 avec Tele 7</h1>" :
#
# ~\Machine_learning\Dossier_ML\Denis\Fonctions.py in arbre(chemin)
#       6 'Fonction qui récupère lurl et renvoit larbre'
#       7 def arbre(chemin):
# ----> 8     page = get(chemin)
#       9     texte = page.text
#      10     arbre = bs4.BeautifulSoup(texte, "lxml")
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     656
#     657         if not stream:
# --> 658             r.content
#     659
#     660         return r
#
# ~\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     821                 self._content = None
#     822             else:
# --> 823                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     824
#     825         self._content_consumed = True
#
# ~\Anaconda3\lib\site-packages\requests\models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
# --> 603                                        flush_decoder=False)
#     604                 if decoded:
#     605                     yield decoded
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _decode(self, data, decode_content, flush_decoder)
#     264         try:
#     265             if decode_content and self._decoder:
# --> 266                 data = self._decoder.decompress(data)
#     267         except (IOError, zlib.error) as e:
#     268             content_encoding = self.headers.get('content-encoding', '').lower()
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in decompress(self, data)
#      64         if not data:
#      65             return data
# ---> 66         return self._obj.decompress(data)
#      67
#      68
#
# KeyboardInterrupt:

# %%
Donnees["Chaine"] = Net.recodage(Donnees["Chaine"], {'35_192"':"TF1",
                                                 '35_80" ':"France 3",
                                                '35_118"':"M6",
                                                 '35_4" h':"France 2",
                                                 '35_195"':"TMC",
                                                '35_47" ':"France 5",
                                                 '35_445"':"C8",
                                                '35_119"':"W9",
                                                 '35_446"':"TFX",
                                                '35_111"':"Arte",
                                                 '35_78" ':"France 4",
                                                '35_444"':"NRJ 12",
                                                 '35_458"':"C Star",
                                                '35_160"':"France O",
                                                 '35_482"':"Gulli",
                                                '35_1402':"RMC Story",
                                                '35_1404':"TF1 Series",
                                                 '35_1400':"RMC Decouverte",
                                                '35_1403':"6ter",
                                                '35_1399':"Cherie 25",
                                                 '35_1400':"RMC Decouverte",
                                                '35_1403':"6ter",
                                                '35_34" ': "Canal +",
                                                '35_234"': "LCP Public Senat",
                                                '35_1401': "L Equipe",
                                                '35_481"': "BFM TV"})

# %%
Donnees1 = Donnees

# %%
import pandas as pd
fusion = pd.merge(Donnees,Donnees1,on=["Date","Chaine"])

# %%
fusion
# Out:
#                     Date     Logo_chaine Part_de_marche  \
# 0      02 septembre 2014             TF1           31.7
# 1      02 septembre 2014        France 3           13.7
# 2      02 septembre 2014              M6           12.4
# 3      02 septembre 2014        France 2           11.6
# 4      02 septembre 2014             TMC            4.9
# 5      02 septembre 2014        France 5            3.4
# 6      02 septembre 2014              C8            3.1
# 7      02 septembre 2014              W9            2.2
# 8      02 septembre 2014             TFX            1.5
# 9      02 septembre 2014            Arte            1.3
# 10     02 septembre 2014        France 4            1.2
# 11     02 septembre 2014          NRJ 12            1.0
# 12     02 septembre 2014          C Star            0.8
# 13     02 septembre 2014        France O            0.8
# 14     02 septembre 2014           Gulli            0.7
# 15     02 septembre 2014       RMC Story            0.5
# 16     02 septembre 2014      TF1 Series            0.4
# 17     02 septembre 2014  RMC Decouverte            0.3
# 18     02 septembre 2014            6ter            0.2
# 19     03 septembre 2014             TF1           27.8
# 20     03 septembre 2014        France 2           12.0
# 21     03 septembre 2014              M6           11.8
# 22     03 septembre 2014        France 3           11.6
# 23     03 septembre 2014             TMC            3.6
# 24     03 septembre 2014              C8            2.7
# 25     03 septembre 2014        France 4            2.2
# 26     03 septembre 2014        France 5            2.2
# 27     03 septembre 2014            Arte            2.2
# 28     03 septembre 2014          C Star            2.1
# 29     03 septembre 2014             TFX            2.0
# ...                  ...             ...            ...
# 31852   24 novembre 2019      TF1 Series            2.5
# 31853   24 novembre 2019            6ter            2.4
# 31854   24 novembre 2019       Cherie 25            2.2
# 31855   24 novembre 2019             TMC            1.9
# 31856   24 novembre 2019  RMC Decouverte            1.9
# 31857   24 novembre 2019              W9            1.4
# 31858   24 novembre 2019              C8            1.1
# 31859   24 novembre 2019          NRJ 12            1.1
# 31860   24 novembre 2019           Gulli            0.8
# 31861   24 novembre 2019       RMC Story            0.4
# 31862   24 novembre 2019          C Star            0.4
# 31863   25 novembre 2019             TF1           27.0
# 31864   25 novembre 2019              M6           14.8
# 31865   25 novembre 2019        France 2            9.6
# 31866   25 novembre 2019        France 3            8.1
# 31867   25 novembre 2019            Arte            5.3
# 31868   25 novembre 2019             TMC            5.1
# 31869   25 novembre 2019              W9            3.6
# 31870   25 novembre 2019              C8            2.8
# 31871   25 novembre 2019          NRJ 12            2.7
# 31872   25 novembre 2019        France 5            2.6
# 31873   25 novembre 2019             TFX            2.3
# 31874   25 novembre 2019        France 4            2.0
# 31875   25 novembre 2019           Gulli            1.6
# 31876   25 novembre 2019  RMC Decouverte            1.3
# 31877   25 novembre 2019      TF1 Series            1.1
# 31878   25 novembre 2019            6ter            0.9
# 31879   25 novembre 2019          C Star            0.9
# 31880   25 novembre 2019       Cherie 25            0.8
# 31881   25 novembre 2019       RMC Story            0.6
#
#                            Date_Chaine
# 0                 02 septembre 2014TF1
# 1            02 septembre 2014France 3
# 2                  02 septembre 2014M6
# 3            02 septembre 2014France 2
# 4                 02 septembre 2014TMC
# 5            02 septembre 2014France 5
# 6                  02 septembre 2014C8
# 7                  02 septembre 2014W9
# 8                 02 septembre 2014TFX
# 9                02 septembre 2014Arte
# 10           02 septembre 2014France 4
# 11             02 septembre 2014NRJ 12
# 12             02 septembre 2014C Star
# 13           02 septembre 2014France O
# 14              02 septembre 2014Gulli
# 15          02 septembre 2014RMC Story
# 16         02 septembre 2014TF1 Series
# 17     02 septembre 2014RMC Decouverte
# 18               02 septembre 20146ter
# 19                03 septembre 2014TF1
# 20           03 septembre 2014France 2
# 21                 03 septembre 2014M6
# 22           03 septembre 2014France 3
# 23                03 septembre 2014TMC
# 24                 03 septembre 2014C8
# 25           03 septembre 2014France 4
# 26           03 septembre 2014France 5
# 27               03 septembre 2014Arte
# 28             03 septembre 2014C Star
# 29                03 septembre 2014TFX
# ...                                ...
# 31852       24 novembre 2019TF1 Series
# 31853             24 novembre 20196ter
# 31854        24 novembre 2019Cherie 25
# 31855              24 novembre 2019TMC
# 31856   24 novembre 2019RMC Decouverte
# 31857               24 novembre 2019W9
# 31858               24 novembre 2019C8
# 31859           24 novembre 2019NRJ 12
# 31860            24 novembre 2019Gulli
# 31861        24 novembre 2019RMC Story
# 31862           24 novembre 2019C Star
# 31863              25 novembre 2019TF1
# 31864               25 novembre 2019M6
# 31865         25 novembre 2019France 2
# 31866         25 novembre 2019France 3
# 31867             25 novembre 2019Arte
# 31868              25 novembre 2019TMC
# 31869               25 novembre 2019W9
# 31870               25 novembre 2019C8
# 31871           25 novembre 2019NRJ 12
# 31872         25 novembre 2019France 5
# 31873              25 novembre 2019TFX
# 31874         25 novembre 2019France 4
# 31875            25 novembre 2019Gulli
# 31876   25 novembre 2019RMC Decouverte
# 31877       25 novembre 2019TF1 Series
# 31878             25 novembre 20196ter
# 31879           25 novembre 2019C Star
# 31880        25 novembre 2019Cherie 25
# 31881        25 novembre 2019RMC Story
#
# [31882 rows x 4 columns]
