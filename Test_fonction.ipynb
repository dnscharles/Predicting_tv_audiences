# %%
import fonctions as fct 
import Listes

# %%
Dates = Listes.date(31,12,6)
Dates
# Out:
# ['01-01-2014',
#  '02-01-2014',
#  '03-01-2014',
#  '04-01-2014',
#  '05-01-2014',
#  '06-01-2014',
#  '01-02-2014',
#  '02-02-2014',
#  '03-02-2014',
#  '04-02-2014',
#  '05-02-2014',
#  '06-02-2014',
#  '01-03-2014',
#  '02-03-2014',
#  '03-03-2014',
#  '04-03-2014',
#  '05-03-2014',
#  '06-03-2014',
#  '01-04-2014',
#  '02-04-2014',
#  '03-04-2014',
#  '04-04-2014',
#  '05-04-2014',
#  '06-04-2014',
#  '01-05-2014',
#  '02-05-2014',
#  '03-05-2014',
#  '04-05-2014',
#  '05-05-2014',
#  '06-05-2014',
#  '01-06-2014',
#  '02-06-2014',
#  '03-06-2014',
#  '04-06-2014',
#  '05-06-2014',
#  '06-06-2014',
#  '01-07-2014',
#  '02-07-2014',
#  '03-07-2014',
#  '04-07-2014',
#  '05-07-2014',
#  '06-07-2014',
#  '01-08-2014',
#  '02-08-2014',
#  '03-08-2014',
#  '04-08-2014',
#  '05-08-2014',
#  '06-08-2014',
#  '01-09-2014',
#  '02-09-2014',
#  '03-09-2014',
#  '04-09-2014',
#  '05-09-2014',
#  '06-09-2014',
#  '01-010-2014',
#  '02-010-2014',
#  '03-010-2014',
#  '04-010-2014',
# ...

# %%
Chemins = Listes.chemin(Dates)
Chemins
# Out:
# ['https://www.programme-television.org/audiences/01-01-2014',
#  'https://www.programme-television.org/audiences/02-01-2014',
#  'https://www.programme-television.org/audiences/03-01-2014',
#  'https://www.programme-television.org/audiences/04-01-2014',
#  'https://www.programme-television.org/audiences/05-01-2014',
#  'https://www.programme-television.org/audiences/06-01-2014',
#  'https://www.programme-television.org/audiences/01-02-2014',
#  'https://www.programme-television.org/audiences/02-02-2014',
#  'https://www.programme-television.org/audiences/03-02-2014',
#  'https://www.programme-television.org/audiences/04-02-2014',
#  'https://www.programme-television.org/audiences/05-02-2014',
#  'https://www.programme-television.org/audiences/06-02-2014',
#  'https://www.programme-television.org/audiences/01-03-2014',
#  'https://www.programme-television.org/audiences/02-03-2014',
#  'https://www.programme-television.org/audiences/03-03-2014',
# ...

# %%
arbre = fct.arbre(Chemins[100])
Chemins[100]
# Out:
# 'https://www.programme-television.org/audiences/05-05-2015'

# %%
fct.Logo(arbre)
# Out:
# ['35_192"',
#  '35_80" ',
#  '35_4" h',
#  '35_118"',
#  '35_47" ',
#  '35_445"',
#  '35_444"',
#  '35_1404',
#  '35_446"',
#  '35_195"',
#  '35_119"',
#  '35_111"',
#  '35_482"',
#  '35_458"',
#  '35_1403',
#  '35_78" ',
#  '35_1400',
#  '35_1402',
#  '35_160"']

# %%
fct.Pdm(arbre)
# Out:
# ['26.4',
#  '12.3',
#  '11.7',
#  '10%<',
#  '4%</',
#  '3.8%',
#  '3.1%',
#  '2.7%',
#  '2.4%',
#  '2.3%',
#  '2.3%',
#  '1.5%',
#  '1.1%',
#  '1%</',
#  '0.8%',
#  '0.6%',
#  '0.5%',
#  '0.4%',
#  '0.4%']

# %%
fct.Jour(arbre)
# Out:
# '05 mai 2015 avec Tele 7</h1>'
