# %%
import Fonctions as Fct 
import Listes
import Generation_df as Gdf
import Nettoyage as Net

# %%
Donnees = Gdf.pd.DataFrame({"Date": [], "Logo_chaîne": [], "Part_de_marché": []})

# %%
Dates = Listes.date(31,12,6)

# %%
Chemins = Listes.chemin(Dates)

# %%
for i in range(len(Chemins)):
    arbre = Fct.arbre(Chemins[i])
    test = arbre.find("h1")
    test = str(test)
    if test != "<h1>Audiences TV du 14 novembre 2019 avec Tele 7</h1>" :
        V1 = Fct.Jour(arbre)
        V2 = Fct.Logo(arbre)
        V3 = Fct.Pdm(arbre)
        if len(V1) == 19 & len(V2) == 19 & len(V3) == 19:
            Donnees = Gdf.Donnee(V1,V2,V3,Donnees)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3b028ba8c800> in <module>()
#       1 for i in range(len(Chemins)):
# ----> 2     arbre = Fct.arbre(Chemins[i])
#       3     test = arbre.find("h1")
#       4     test = str(test)
#       5     if test != "<h1>Audiences TV du 14 novembre 2019 avec Tele 7</h1>" :
#
# ~\Machine_learning\Dossier\Fonctions.py in arbre(chemin)
#       6 'Fonction qui récupère lurl et renvoit larbre'
#       7 def arbre(chemin):
# ----> 8     page = get(chemin)
#       9     texte = page.text
#      10     arbre = bs4.BeautifulSoup(texte, "lxml")
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     497
#     498         settings = self.merge_environment_settings(
# --> 499             prep.url, proxies, stream, verify, cert
#     500         )
#     501
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in merge_environment_settings(self, url, proxies, stream, verify, cert)
#     670             # Set environment's proxies.
#     671             no_proxy = proxies.get('no_proxy') if proxies is not None else None
# --> 672             env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     673             for (k, v) in env_proxies.items():
#     674                 proxies.setdefault(k, v)
#
# ~\Anaconda3\lib\site-packages\requests\utils.py in get_environ_proxies(url, no_proxy)
#     690     :rtype: dict
#     691     """
# --> 692     if should_bypass_proxies(url, no_proxy=no_proxy):
#     693         return {}
#     694     else:
#
# ~\Anaconda3\lib\site-packages\requests\utils.py in should_bypass_proxies(url, no_proxy)
#     674     with set_environ('no_proxy', no_proxy_arg):
#     675         try:
# --> 676             bypass = proxy_bypass(netloc)
#     677         except (TypeError, socket.gaierror):
#     678             bypass = False
#
# ~\Anaconda3\lib\site-packages\requests\utils.py in proxy_bypass(host)
#      85             return proxy_bypass_environment(host)
#      86         else:
# ---> 87             return proxy_bypass_registry(host)
#      88
#      89
#
# ~\Anaconda3\lib\site-packages\requests\utils.py in proxy_bypass_registry(host)
#      50         try:
#      51             internetSettings = winreg.OpenKey(winreg.HKEY_CURRENT_USER,
# ---> 52                 r'Software\Microsoft\Windows\CurrentVersion\Internet Settings')
#      53             proxyEnable = winreg.QueryValueEx(internetSettings,
#      54                                               'ProxyEnable')[0]
#
# KeyboardInterrupt:

# %%
Donnees["Logo_chaîne"] = Net.recodage(Donnees["Logo_chaîne"], {'35_192"':"TF1",
                                                 '35_80" ':"France 3",
                                                '35_118"':"M6",
                                                 '35_4" h':"France 2",
                                                 '35_195"':"TMC",
                                                '35_47" ':"France 5",
                                                 '35_445"':"C8",
                                                '35_119"':"W9",
                                                 '35_446"':"TFX",
                                                '35_111"':"Arte",
                                                 '35_78" ':"France 4",
                                                '35_444"':"NRJ 12",
                                                 '35_458"':"C Star",
                                                '35_160"':"France Ô",
                                                 '35_482"':"Gulli",
                                                '35_1402':"RMC Story",
                                                '35_1404':"TF1 Séries",
                                                 '35_1400':"RMC Découverte",
                                                '35_1403':"6ter"})

# %%
Donnees
# Out:
#                   Date     Logo_chaîne Part_de_marché
# 0    02 septembre 2014             TF1           31.7
# 1    02 septembre 2014        France 3           13.7
# 2    02 septembre 2014              M6           12.4
# 3    02 septembre 2014        France 2           11.6
# 4    02 septembre 2014             TMC           4.9%
# 5    02 septembre 2014        France 5           3.4%
# 6    02 septembre 2014              C8           3.1%
# 7    02 septembre 2014              W9           2.2%
# 8    02 septembre 2014             TFX           1.5%
# 9    02 septembre 2014            Arte           1.3%
# 10   02 septembre 2014        France 4           1.2%
# 11   02 septembre 2014          NRJ 12           1.0%
# 12   02 septembre 2014          C Star           0.8%
# 13   02 septembre 2014        France Ô           0.8%
# 14   02 septembre 2014           Gulli           0.7%
# 15   02 septembre 2014       RMC Story           0.5%
# 16   02 septembre 2014      TF1 Séries           0.4%
# 17   02 septembre 2014  RMC Découverte           0.3%
# 18   02 septembre 2014            6ter           0.2%
# 19   03 septembre 2014             TF1           27.8
# 20   03 septembre 2014        France 2           12.0
# 21   03 septembre 2014              M6           11.8
# 22   03 septembre 2014        France 3           11.6
# 23   03 septembre 2014             TMC           3.6%
# 24   03 septembre 2014              C8           2.7%
# 25   03 septembre 2014        France 4           2.2%
# 26   03 septembre 2014        France 5           2.2%
# 27   03 septembre 2014            Arte           2.2%
# 28   03 septembre 2014          C Star           2.1%
# 29   03 septembre 2014             TFX           2.0%
# ..                 ...             ...            ...
# 255   05 décembre 2014        France 5           2.6%
# 256   05 décembre 2014            Arte           2.3%
# 257   05 décembre 2014           Gulli           1.9%
# 258   05 décembre 2014             TFX           1.5%
# 259   05 décembre 2014          C Star           1.3%
# 260   05 décembre 2014        France 4           0.8%
# 261   05 décembre 2014      TF1 Séries           0.8%
# 262   05 décembre 2014        France Ô           0.8%
# 263   05 décembre 2014  RMC Découverte           0.7%
# 264   05 décembre 2014       RMC Story           0.6%
# 265   05 décembre 2014            6ter           0.5%
# 266   06 décembre 2014             TF1           40.5
# 267   06 décembre 2014              M6           11.3
# 268   06 décembre 2014        France 3           10.6
# 269   06 décembre 2014        France 2           10.2
# 270   06 décembre 2014        France 5           4.5%
# 271   06 décembre 2014            Arte           2.9%
# 272   06 décembre 2014              W9           2.9%
# 273   06 décembre 2014        France 4           2.5%
# 274   06 décembre 2014             TMC           2%</
# 275   06 décembre 2014          NRJ 12           1.9%
# 276   06 décembre 2014              C8           1.8%
# 277   06 décembre 2014             TFX           1.5%
# 278   06 décembre 2014      TF1 Séries           1.3%
# 279   06 décembre 2014           Gulli           1.1%
# 280   06 décembre 2014  RMC Découverte           1%</
# 281   06 décembre 2014            6ter           0.9%
# 282   06 décembre 2014          C Star           0.8%
# 283   06 décembre 2014       RMC Story           0.2%
# 284   06 décembre 2014        France Ô           0.2%
#
# [285 rows x 3 columns]
