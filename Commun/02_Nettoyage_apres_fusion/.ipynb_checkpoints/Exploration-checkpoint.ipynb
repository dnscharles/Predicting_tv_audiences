# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats as st

# %%
data = pd.read_csv("Base_donnees.csv", sep=",")

# %%
data.head()
# Out:
#    Unnamed: 0             Date      Jour    Chaine  Heure_prgm1  \
# 0           0  08 octobre 2014  mercredi       TF1        20.55
# 1           1  08 octobre 2014  mercredi  France 2        20.50
# 2           2  08 octobre 2014  mercredi  France 3        20.45
# 3           3  08 octobre 2014  mercredi   Canal +        20.55
# 4           4  08 octobre 2014  mercredi  France 5        20.40
#
#                 Titre_prgm1 Type_prgm1 Duree_prgm1  Nbre_episodes_prgm1  \
# 0                 Blacklist   Serie TV         110                  2.0
# 1     Les hommes de l'ombre   Serie TV         120                  2.0
# 2  Des racines et des ailes   Magazine         115                  0.0
# 3                     Diana       Film         110                  0.0
# 4        La maison France 5   Magazine         60                   0.0
#
#   Age_conseille_prgm1  Heure_prgm2               Titre_prgm2 Type_prgm2  \
# 0             -10 ans        22.40                     Arrow   Serie TV
# 1                 NaN        22.40  Un soir à la tour Eiffel   Magazine
# 2                 NaN        23.36              Le comte Ory      Opera
# 3                 NaN        22.45              9 mois ferme       Film
# 4                 NaN        21.40      Silence, ça pousse !   Magazine
#
#   Duree_prgm2  Nbre_episodes_prgm2 Age_conseille_prgm2 Part_de_marche
# 0         100                  3.0             -10 ans           24.4
# 1         100                  0.0                 NaN           13.1
# 2         144                  0.0                 NaN             12
# 3         80                   0.0                 NaN            NaN
# 4         49                   0.0                 NaN            2.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48259 entries, 0 to 48258
# Data columns (total 17 columns):
# Unnamed: 0             48259 non-null int64
# Date                   48259 non-null object
# Jour                   47439 non-null object
# Chaine                 48253 non-null object
# Heure_prgm1            47439 non-null float64
# Titre_prgm1            46749 non-null object
# Type_prgm1             46747 non-null object
# Duree_prgm1            47439 non-null object
# Nbre_episodes_prgm1    47439 non-null float64
# Age_conseille_prgm1    10367 non-null object
# Heure_prgm2            38638 non-null float64
# Titre_prgm2            47045 non-null object
# Type_prgm2             47040 non-null object
# Duree_prgm2            38638 non-null object
# Nbre_episodes_prgm2    47439 non-null float64
# Age_conseille_prgm2    7796 non-null object
# Part_de_marche         31999 non-null object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 6.3+ MB

# %% [markdown]
# ## Gestion unnamed

# %%
data = data.drop(data.columns[0],axis='columns')

# %% [markdown]
# ## Gestion date

# %%
def annee(string):
    parts = string.split(' ')
    return parts[2]
def mois(string):
    parts = string.split(' ')
    return parts[1]

# %%
data['Annee'] = data['Date']
data['Annee'] = data['Annee'].apply(annee)
data['Mois'] = data['Date']
data['Mois'] = data['Mois'].apply(mois)

# %%
data.head()
# Out:
#               Date      Jour    Chaine  Heure_prgm1               Titre_prgm1  \
# 0  08 octobre 2014  mercredi       TF1        20.55                 Blacklist
# 1  08 octobre 2014  mercredi  France 2        20.50     Les hommes de l'ombre
# 2  08 octobre 2014  mercredi  France 3        20.45  Des racines et des ailes
# 3  08 octobre 2014  mercredi   Canal +        20.55                     Diana
# 4  08 octobre 2014  mercredi  France 5        20.40        La maison France 5
#
#   Type_prgm1 Duree_prgm1  Nbre_episodes_prgm1 Age_conseille_prgm1  \
# 0   Serie TV         110                  2.0             -10 ans
# 1   Serie TV         120                  2.0                 NaN
# 2   Magazine         115                  0.0                 NaN
# 3       Film         110                  0.0                 NaN
# 4   Magazine         60                   0.0                 NaN
#
#    Heure_prgm2               Titre_prgm2 Type_prgm2 Duree_prgm2  \
# 0        22.40                     Arrow   Serie TV         100
# 1        22.40  Un soir à la tour Eiffel   Magazine         100
# 2        23.36              Le comte Ory      Opera         144
# 3        22.45              9 mois ferme       Film         80
# 4        21.40      Silence, ça pousse !   Magazine         49
#
#    Nbre_episodes_prgm2 Age_conseille_prgm2 Part_de_marche Annee     Mois
# 0                  3.0             -10 ans           24.4  2014  octobre
# 1                  0.0                 NaN           13.1  2014  octobre
# 2                  0.0                 NaN             12  2014  octobre
# 3                  0.0                 NaN            NaN  2014  octobre
# 4                  0.0                 NaN            2.6  2014  octobre

# %% [markdown]
# ## Gestion Jour (week-end ou non ?)

# %%
def weekend(string):
    if string == 'samedi' or string == 'dimanche':
        D = 1
    else:
        D = 0
    return D

# %%
data['Week end'] = data['Jour']
data['Week end'] = data['Week end'].apply(weekend)

# %% [markdown]
# ## Gestion chaîne

# %%
def Tableau_freq(effectifs):
    modalites = effectifs.index # l'index de effectifs contient les modalités

    tab = pd.DataFrame(modalites, columns = ["Programme"]) # création du tableau à partir des modalités
    tab["n"] = effectifs.values
    tab["f"] = (tab["n"] / len(data))*100 # len(data) renvoie la taille de l'échantillon
    return tab

# %%
effectifs = data["Chaine"].value_counts()
Tableau_freq(effectifs)
# Out:
#            Programme     n         f
# 0     RMC Decouverte  1953  4.046914
# 1           France 4  1952  4.044841
# 2                 M6  1951  4.042769
# 3                TMC  1951  4.042769
# 4               Arte  1951  4.042769
# 5           France 3  1950  4.040697
# 6           France 2  1948  4.036553
# 7           France 5  1948  4.036553
# 8                 C8  1947  4.034481
# 9                 W9  1947  4.034481
# 10            NRJ 12  1947  4.034481
# 11               TF1  1947  4.034481
# 12            C Star  1946  4.032408
# 13              6ter  1946  4.032408
# 14        TF1 Series  1946  4.032408
# 15               TFX  1945  4.030336
# 16         RMC Story  1944  4.028264
# 17             Gulli  1942  4.024120
# 18          France O  1920  3.978533
# 19         Cherie 25  1905  3.947450
# 20           Canal +  1870  3.874925
# 21          L Equipe  1866  3.866636
# 22            C News  1848  3.829338
# 23  LCP Public Senat  1816  3.763029
# 24            BFM TV  1814  3.758884
# 25             RTL 9   136  0.281813
# 26           35_" hr    17  0.035227

# %% [markdown]
# RTL 9 et l'autre apparaissent très peu de fois, on les enlève.

# %%
data = data.drop(data[data.Chaine == 'RTL 9'].index)
data = data.drop(data[data.Chaine == '35_" hr'].index)

# %%
effectifs = data["Chaine"].value_counts()
Tableau_freq(effectifs)
# Out:
#            Programme     n         f
# 0     RMC Decouverte  1953  4.059785
# 1           France 4  1952  4.057706
# 2               Arte  1951  4.055627
# 3                TMC  1951  4.055627
# 4                 M6  1951  4.055627
# 5           France 3  1950  4.053548
# 6           France 5  1948  4.049391
# 7           France 2  1948  4.049391
# 8                 W9  1947  4.047312
# 9                 C8  1947  4.047312
# 10            NRJ 12  1947  4.047312
# 11               TF1  1947  4.047312
# 12            C Star  1946  4.045233
# 13        TF1 Series  1946  4.045233
# 14              6ter  1946  4.045233
# 15               TFX  1945  4.043155
# 16         RMC Story  1944  4.041076
# 17             Gulli  1942  4.036918
# 18          France O  1920  3.991186
# 19         Cherie 25  1905  3.960005
# 20           Canal +  1870  3.887249
# 21          L Equipe  1866  3.878934
# 22            C News  1848  3.841517
# 23  LCP Public Senat  1816  3.774997
# 24            BFM TV  1814  3.770839

# %% [markdown]
# ## Gestion heure programme

# %%
effectifs = data["Heure_prgm1"].value_counts()
tab = Tableau_freq(effectifs)

# %%
tab.to_csv('heure prog.csv',index=False)

# %% [markdown]
# ## Gestion type programme

# %%
effectifs = data["Type_prgm2"].value_counts()
Tableau_freq(effectifs)
# Out:
#               Programme      n          f
# 0              Magazine  13831  28.751091
# 1              Serie TV   8063  16.760903
# 2          Documentaire   7268  15.108302
# 3                  Film   6149  12.782189
# 4              Telefilm   3843   7.988608
# 5        Divertissement   2085   4.334179
# 6           Information   1447   3.007941
# 7          Telerealitee   1356   2.818775
# 8             Spectacle    643   1.336632
# 9             Talk-Show    527   1.095497
# 10                Sport    366   0.760820
# 11              Concert    290   0.602835
# 12              Journal    264   0.548788
# 13         Dessin-anime    179   0.372095
# 14                Debat    160   0.332599
# 15                  Jeu    125   0.259843
# 16                Opera     89   0.185008
# 17              Theatre     75   0.155906
# 18               Ballet     32   0.066520
# 19            Ceremonie     28   0.058205
# 20                 Gala     21   0.043654
# 21        Court-metrage     21   0.043654
# 22      Programme Court     13   0.027024
# 23            Reportage      8   0.016630
# 24                Danse      5   0.010394
# 25  Emission religieuse      5   0.010394
# 26                Clips      4   0.008315
# 27              Musique      3   0.006236
# 28            Making-of      2   0.004157
# 29    Fin des emissions      2   0.004157

# %%
def Prog(string):
    if string == 'Telerealitee' or string == 'Jeu' or string == 'Spectacle' or string == 'Concert' or string == 'Theatre' or string == 'Dessin-anime' or string == 'Ceremonie' or string == 'Gala' or string == 'Opera' or string == 'Clips' or string == 'Talk-Show' or string == 'Danse' or string == 'Musique' or string == 'Ballet':
        P = 'Divertissement'
    elif string == 'Reportage' or string == 'Making-of':
        P = 'Magazine'
    elif string == 'Journal' or string == 'Debat':
        P = 'Information'
    else:
        P = string
    return P

# %%
data['Type_prgm1'] = data['Type_prgm1'].apply(Prog)
data['Type_prgm2'] = data['Type_prgm2'].apply(Prog)

# %%
data = data.drop(data[data.Type_prgm1 == 'Court-metrage'].index)
data = data.drop(data[data.Type_prgm1 == 'Programme Court'].index)
data = data.drop(data[data.Type_prgm2 == 'Court-metrage'].index)
data = data.drop(data[data.Type_prgm2 == 'Programme Court'].index)
data = data.drop(data[data.Type_prgm2 == 'Emission religieuse'].index)
data = data.drop(data[data.Type_prgm2 == 'Fin des emissions'].index)

# %%
effectifs = data["Type_prgm1"].value_counts()
Tableau_freq(effectifs)
# Out:
#         Programme      n          f
# 0        Serie TV  10050  20.913972
# 1            Film   9614  20.006659
# 2        Magazine   8780  18.271112
# 3    Documentaire   6290  13.089441
# 4  Divertissement   4983  10.369584
# 5        Telefilm   3584   7.458276
# 6           Sport   2112   4.395056
# 7     Information   1147   2.386898

# %%
effectifs = data["Type_prgm2"].value_counts()
Tableau_freq(effectifs)
# Out:
#         Programme      n          f
# 0        Magazine  13841  28.803013
# 1        Serie TV   8055  16.762392
# 2    Documentaire   7268  15.124651
# 3            Film   6147  12.791859
# 4  Divertissement   5462  11.366379
# 5        Telefilm   3842   7.995172
# 6     Information   1871   3.893536
# 7           Sport    366   0.761643

# %%
data["Type_prgm1"].value_counts(normalize=True).plot(kind='pie')
plt.axis('equal') 
plt.show()

# %%
data["Type_prgm2"].value_counts(normalize=True).plot(kind='pie')
plt.axis('equal') 
plt.show()

# %%
data["Type_prgm1"].value_counts().plot(kind='bar')
plt.show()

# %%
data["Type_prgm2"].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Gestion duree programme

# %%
def Duree_prog(string):
    parts = string.split(' ')
    if string == "nan":
        return np.nan
    else:
        return parts[0]

# %%
data['Duree_prgm1'] = data['Duree_prgm1'].astype(str)
data['Duree_prgm1'] = data['Duree_prgm1'].apply(Duree_prog)
data
# Out:
#                    Date      Jour     Chaine  Heure_prgm1  \
# 0       08 octobre 2014  mercredi        TF1        20.55
# 1       08 octobre 2014  mercredi   France 2        20.50
# 2       08 octobre 2014  mercredi   France 3        20.45
# 3       08 octobre 2014  mercredi    Canal +        20.55
# 4       08 octobre 2014  mercredi   France 5        20.40
# ...                 ...       ...        ...          ...
# 48254  02 décembre 2019       NaN       6ter          NaN
# 48255  02 décembre 2019       NaN  Cherie 25          NaN
# 48256  02 décembre 2019       NaN      Gulli          NaN
# 48257  02 décembre 2019       NaN  RMC Story          NaN
# 48258  02 décembre 2019       NaN     C Star          NaN
#
#                     Titre_prgm1 Type_prgm1 Duree_prgm1  Nbre_episodes_prgm1  \
# 0                     Blacklist   Serie TV         110                  2.0
# 1         Les hommes de l'ombre   Serie TV         120                  2.0
# 2      Des racines et des ailes   Magazine         115                  0.0
# 3                         Diana       Film         110                  0.0
# 4            La maison France 5   Magazine          60                  0.0
# ...                         ...        ...         ...                  ...
# 48254                       NaN        NaN         nan                  NaN
# 48255                       NaN        NaN         nan                  NaN
# 48256                       NaN        NaN         nan                  NaN
# 48257                       NaN        NaN         nan                  NaN
# 48258                       NaN        NaN         nan                  NaN
#
#       Age_conseille_prgm1  Heure_prgm2               Titre_prgm2  \
# 0                 -10 ans        22.40                     Arrow
# 1                     NaN        22.40  Un soir à la tour Eiffel
# 2                     NaN        23.36              Le comte Ory
# 3                     NaN        22.45              9 mois ferme
# 4                     NaN        21.40      Silence, ça pousse !
# ...                   ...          ...                       ...
# 48254                 NaN          NaN                       NaN
# 48255                 NaN          NaN                       NaN
# 48256                 NaN          NaN                       NaN
# 48257                 NaN          NaN                       NaN
# 48258                 NaN          NaN                       NaN
#
#            Type_prgm2 Duree_prgm2  Nbre_episodes_prgm2 Age_conseille_prgm2  \
# 0            Serie TV         100                  3.0             -10 ans
# 1            Magazine         100                  0.0                 NaN
# 2      Divertissement         144                  0.0                 NaN
# 3                Film         80                   0.0                 NaN
# 4            Magazine         49                   0.0                 NaN
# ...               ...         ...                  ...                 ...
# 48254             NaN         NaN                  NaN                 NaN
# 48255             NaN         NaN                  NaN                 NaN
# 48256             NaN         NaN                  NaN                 NaN
# 48257             NaN         NaN                  NaN                 NaN
# 48258             NaN         NaN                  NaN                 NaN
#
#       Part_de_marche Annee      Mois  Week end
# 0               24.4  2014   octobre         0
# 1               13.1  2014   octobre         0
# 2                 12  2014   octobre         0
# 3                NaN  2014   octobre         0
# 4                2.6  2014   octobre         0
# ...              ...   ...       ...       ...
# 48254            1.3  2019  décembre         0
# 48255            1.2  2019  décembre         0
# 48256            1.1  2019  décembre         0
# 48257            0.9  2019  décembre         0
# 48258            0.4  2019  décembre         0
#
# [48054 rows x 19 columns]

# %%
effectifs = data["Duree_prgm1"].value_counts()
tab = Tableau_freq(effectifs)
tab.to_csv('duree prog.csv',index=False)

# %%
def Duree_prog_na(duree):
    if duree == "nan":
        return np.nan
    return duree

# %%
data['Duree_prgm1'] = data['Duree_prgm1'].apply(Duree_prog_na)
print(data['Duree_prgm1'].isna().sum())
data['Duree_prgm2'] = data['Duree_prgm2'].apply(Duree_prog_na)
print(data['Duree_prgm2'].isna().sum())
# Out:
# 803
# 9603

# %%
for cat in data["Type_prgm1"].unique():
    subset = data[data.Type_prgm1 == cat] # Création du sous-échantillon
    print("-"*20)
    print(cat)
    print("moy:\n",subset['Duree_prgm1'].mean())
    print("med:\n",subset['Duree_prgm1'].median())
    print("mod:\n",subset['Duree_prgm1'].mode())
    subset["Duree_prgm1"].hist() # Crée l'histogramme
    plt.show() # Affiche l'histogramme
# Out:
# --------------------
# Serie TV
# moy:
#  inf
# med:
#  110.0
# mod:
#  0    110
# dtype: object
# --------------------
# Magazine
# moy:
#  inf
# med:
#  110.0
# mod:
#  0    60
# dtype: object
# --------------------
# Film
# moy:
#  inf
# med:
#  115.0
# mod:
#  0    120
# dtype: object
# --------------------
# Divertissement
# moy:
#  inf
# med:
#  130.0
# mod:
#  0    100
# dtype: object
# --------------------
# Documentaire
# moy:
#  inf
# med:
#  90.0
# mod:
#  0    60
# dtype: object
# --------------------
# Telefilm
# moy:
#  inf
# med:
#  100.0
# mod:
#  0    100
# dtype: object
# --------------------
# Sport
# moy:
#  inf
# med:
#  120.0
# mod:
#  0    120
# dtype: object
# --------------------
# Information
# moy:
#  inf
# med:
#  90.0
# mod:
#  0    60
# dtype: object
# --------------------
# nan
# moy:
#  nan
# med:
#  nan
# mod:
#  Series([], dtype: object)

# %% [markdown]
# ## Gestion part de marché

# %%
def Pdm(string):
    if string == "nan":
        return np.nan
    else:
        P = string.replace(",",".")
        return P

# %%
data['Part_de_marche'] = data['Part_de_marche'].astype(str)
data['Part_de_marche'] = data['Part_de_marche'].apply(Pdm)
print(data['Part_de_marche'].isna().sum())
# Out:
# 16085

# %%
data.to_csv('base propre.csv',index=False)

# %% [markdown]
# # Avec le fichier .py

# %%
import Nettoyage_base

# %%
data = Nettoyage_base.pd.read_csv("Base_donnees.csv", sep=",")

# %%
data = Nettoyage_base.nettoyage(data)

# %%
data.to_csv('base propre.csv',index=False)
