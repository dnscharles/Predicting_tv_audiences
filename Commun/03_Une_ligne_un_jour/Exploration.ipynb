# %%
import pandas as pd

# %%
resultat = pd.read_csv("base propre.csv")

# %%
resultat.Chaine.unique()
# Out:
# array(['TF1', 'France 2', 'France 3', 'Canal +', 'France 5', 'M6', 'Arte',
#        'C8', 'W9', 'TMC', 'TFX', 'NRJ 12', 'LCP Public Senat', 'France 4',
#        'BFM TV', 'C News', 'C Star', 'Gulli', 'France O', '6ter',
#        'TF1 Series', 'L Equipe', 'RMC Story', 'RMC Decouverte',
#        'Cherie 25', nan], dtype=object)

# %%
#Data frame par chaîne
TF1 = resultat.loc[resultat['Chaine']=="TF1",:]
Fr2 = resultat.loc[resultat['Chaine']=="France 2",:]
Fr3 = resultat.loc[resultat['Chaine']=="France 3",:]
Cplus = resultat.loc[resultat['Chaine']=="Canal +",:]
Fr5 = resultat.loc[resultat['Chaine']=="France 5",:]
M6 = resultat.loc[resultat['Chaine']=="M6",:]
Arte = resultat.loc[resultat['Chaine']=="Arte",:]
C8 = resultat.loc[resultat['Chaine']=="C8",:]
W9 = resultat.loc[resultat['Chaine']=="W9",:]
TMC = resultat.loc[resultat['Chaine']=="TMC",:]
TFX = resultat.loc[resultat['Chaine']=="TFX",:]
NRJ12 = resultat.loc[resultat['Chaine']=="NRJ 12",:]
LCP = resultat.loc[resultat['Chaine']=="LCP Public Senat",:]
Fr4 = resultat.loc[resultat['Chaine']=="France 4",:]
BFM = resultat.loc[resultat['Chaine']=="BFM TV",:]
Cnews = resultat.loc[resultat['Chaine']=="C News",:]
Cstar = resultat.loc[resultat['Chaine']=="C Star",:]
Gulli = resultat.loc[resultat['Chaine']=="Gulli",:]
FrO = resultat.loc[resultat['Chaine']=="France O",:]
TF1series = resultat.loc[resultat['Chaine']=="TF1 Series",:]
Equipe = resultat.loc[resultat['Chaine']=="L Equipe",:]
Sixter = resultat.loc[resultat['Chaine']=="6ter",:]
RMCstory = resultat.loc[resultat['Chaine']=="RMC Story",:]
RMCdecou = resultat.loc[resultat['Chaine']=="RMC Decouverte",:]
Cherie25 = resultat.loc[resultat['Chaine']=="Cherie 25",:]

# %%
fusion = pd.merge(TF1,Fr2, on="Date")
fusion = pd.merge(fusion,Fr3, on="Date")
fusion = pd.merge(fusion,Cplus, on="Date")
fusion = pd.merge(fusion,Fr5, on="Date")
fusion = pd.merge(fusion,M6, on="Date")
fusion = pd.merge(fusion,Arte, on="Date")
fusion = pd.merge(fusion,C8, on="Date")
fusion = pd.merge(fusion,W9, on="Date")
fusion = pd.merge(fusion,TMC, on="Date")
fusion = pd.merge(fusion,NRJ12, on="Date")
fusion = pd.merge(fusion,Fr4, on="Date")
fusion = pd.merge(fusion,Cstar, on="Date")
fusion = pd.merge(fusion,Gulli, on="Date")
fusion = pd.merge(fusion,FrO, on="Date")
fusion = pd.merge(fusion,TF1series, on="Date")
fusion = pd.merge(fusion,Equipe, on="Date")
fusion = pd.merge(fusion,Sixter, on="Date")
fusion = pd.merge(fusion,RMCstory, on="Date")
fusion = pd.merge(fusion,RMCdecou, on="Date")
fusion = pd.merge(fusion,Cherie25, on="Date")
fusion
# Out:
#                     Date    Jour_x Chaine_x  Heure_prgm1_x  \
# 0        08 octobre 2014  mercredi      TF1          20.55
# 1        09 octobre 2014     jeudi      TF1          20.55
# 2        10 octobre 2014  vendredi      TF1          20.55
# 3        11 octobre 2014    samedi      TF1          20.35
# 4        12 octobre 2014  dimanche      TF1          20.55
# ...                  ...       ...      ...            ...
# 120510  16 novembre 2019    samedi      TF1          21.05
# 120511  17 novembre 2019  dimanche      TF1          20.35
# 120512  18 novembre 2019     lundi      TF1          21.05
# 120513  19 novembre 2019     mardi      TF1          21.05
# 120514  20 novembre 2019  mercredi      TF1          21.05
#
#                              Titre_prgm1_x    Type_prgm1_x  Duree_prgm1_x  \
# 0                                Blacklist        Serie TV          110.0
# 1                           Crossing Lines        Serie TV          120.0
# ...

# %%
fusion = pd.DataFrame(fusion)

# %%
fusion.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-cd0aa6ddf023> in <module>
# ----> 1 fusion.dtypes()
#
# TypeError: 'Series' object is not callable
